# %% [markdown]
# Reference: https://github.com/hlamba28/Offline-Signature-Verification-using-Siamese-Network/blob/master/SigNet-BHSig260.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/sounakdey/SigNet.git /content/drive/MyDrive/SignatureVerificationCylab/SigNet
# Out:
# Cloning into '/content/drive/MyDrive/SignatureVerificationCylab/SigNet'...
# remote: Enumerating objects: 89, done.
# remote: Total 89 (delta 0), reused 0 (delta 0), pack-reused 89
# Receiving objects: 100% (89/89), 2.05 MiB | 11.36 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# !mkdir /content/drive/MyDrive/SignatureVerificationCylab/SigNetDeepSign

# %%
# %cd /content/drive/MyDrive/SignatureVerificationCylab/SigNetDeepSign
# Out:
# /content/drive/MyDrive/SignatureVerificationCylab/SigNetDeepSign

# %%
# !mkdir /content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset

# %%
# !unzip /content/drive/MyDrive/SignatureVerificationCylab/cedar_dataset.zip -d /content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
from __future__ import absolute_import
from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility
import os

#from keras.utils.visualize_util import plot

# import tensorflow as tf
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras.layers import Dense, Dropout, Input, Lambda, Flatten, Convolution2D, MaxPooling2D, ZeroPadding2D
# from keras.preprocessing import image
import keras.utils as image
from keras import backend as K
import sys
import glob
import logging
from keras.models import Sequential, Model
from keras.optimizers import SGD, RMSprop, Adadelta
from tensorflow.keras.layers import BatchNormalization
# from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
import random
random.seed(1337)

# %%
import sys
import numpy as np
import pandas as pd
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time
import itertools
import random

from sklearn.utils import shuffle

# import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam, RMSprop
from keras.layers import Dense, Dropout, Input, Lambda, Flatten, Convolution2D, MaxPooling2D, ZeroPadding2D
# from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate, Dropout
from keras.models import Sequential, Model

from tensorflow.keras.layers import BatchNormalization
from keras.layers.pooling import MaxPooling2D
from keras.layers import concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform

# from keras.engine.topology import Layer
from tensorflow.keras.layers import Layer
from keras.regularizers import l2
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# Create a session for running Ops on the Graph.
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
K.set_session(sess)

logging.basicConfig(level=logging.WARNING)
log = logging.getLogger()

# %%
mcyt_df = pd.read_csv("/content/drive/MyDrive/SignatureVerificationCylab/MCYT_training.csv")

# %%
mcyt_df
# Out:
#        Unnamed: 0             filename user id tag
# 0               0  u0001_g_0100v01.txt   u0001   g
# 1               1  u0001_g_0100v00.txt   u0001   g
# 2               2  u0216_g_0420v23.txt   u0216   g
# 3               3  u0216_g_0420v17.txt   u0216   g
# 4               4  u0216_g_0420v16.txt   u0216   g
# ...           ...                  ...     ...  ..
# 11495       11495  u0015_s_0114f22.txt   u0015   s
# 11496       11496  u0015_s_0114f17.txt   u0015   s
# 11497       11497  u0016_g_0115v17.txt   u0016   g
# 11498       11498  u0016_g_0115v13.txt   u0016   g
# 11499       11499  u0016_g_0115v10.txt   u0016   g
#
# [11500 rows x 4 columns]

# %%
signers = mcyt_df["user id"].unique()

# %%
signers_train = sorted(signers[:30])
signers_val = sorted(signers[30:40])
signers_test = sorted(signers[40:55])

# %%
def extract_genuine_forged(user_id, df, tag):
  base_path = "/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images"
  filenames = []
  if tag == "g":
      user_id_df = df[(df["user id"] == user_id) &  (df["tag"] == "g")]
  elif tag == "s":
      user_id_df = df[(df["user id"] == user_id) &  (df["tag"] == "s")]


  filenames = [os.path.join(base_path,filename.split(".")[0] + ".jpg") for filename in user_id_df["filename"]]

  return filenames

# %%
# # from keras.engine import base_layer_utils
# base_path = "/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/"

# %%
# # Get the list of all directories and sort them
# dir_list = [folder for folder in os.listdir(base_path) if os.path.isdir(os.path.join(base_path,folder))]
# dir_list.sort()

# dir_list = dir_list[1:]

# %%
# print(dir_list)

# %%
# # For each person segregate the genuine signatures from the forged signatures
# # Genuine signatures are stored in the list "orig_groups"
# # Forged signatures are stored in the list "forged_groups"
# orig_groups, forg_groups = [], []
# num = 24 # Number of genuine or forged

# def split_into_batches(input_list, num_images):
#     for i in range(0, len(input_list), num_images):
#         yield input_list[i:i + num_images]

# for directory in dir_list:
#     images = os.listdir(base_path+directory)
#     images.sort()
#     images = [base_path+directory+'/'+x for x in images if x != "Thumbs.db"]

#     batches = list(split_into_batches(images, num))

#     if directory == "full_forg":
#         forg_groups.append(batches) # First 24 signatures in each folder are forrged
#     elif directory == "full_org":
#         orig_groups.append(batches)

# %%
# len(orig_groups[0])

# %%
# len(forg_groups[0])

# %%
# orig_groups;

# %%
mcyt_df["user id"]
# Out:
# 0        u0001
# 1        u0001
# 2        u0216
# 3        u0216
# 4        u0216
#          ...
# 11495    u0015
# 11496    u0015
# 11497    u0016
# 11498    u0016
# 11499    u0016
# Name: user id, Length: 11500, dtype: object

# %%
orig_train = []
for signer in signers_train:
  orig_train.append(extract_genuine_forged(signer, mcyt_df, "g"))

orig_val = []
for signer in signers_val:
  orig_val.append(extract_genuine_forged(signer, mcyt_df, "g"))

orig_test = []
for signer in signers_test:
  orig_test.append(extract_genuine_forged(signer, mcyt_df, "g"))

# %%
forg_train = []
for signer in signers_train:
  forg_train.append(extract_genuine_forged(signer, mcyt_df, "s"))

forg_val = []
for signer in signers_val:
  forg_val.append(extract_genuine_forged(signer, mcyt_df, "s"))

forg_test = []
for signer in signers_test:
  forg_test.append(extract_genuine_forged(signer, mcyt_df, "s"))

# %%
orig_train
# Out:
# [['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v19.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v07.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v18.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v18.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v17.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v23.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v23.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v20.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_g_0409v23.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_g_0410v22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_g_0411v12.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_g_0412v19.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_g_0413v24.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_g_0420v11.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_g_0421v19.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_g_0422v22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_g_0423v20.jpg'],
# ...
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_g_0428v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_g_0428v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_g_0428v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_g_0428v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_g_0428v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_g_0428v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_g_0428v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_g_0428v12.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_g_0429v16.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_g_0430v24.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_g_0431v22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_g_0432v11.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_g_0433v18.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_g_0434v15.jpg']]

# %%
# orig_lengths = [len(x) for x in orig_groups[0]]
# forg_lengths = [len(x) for x in forg_groups[0]]

# %%
# orig_lengths, forg_lengths;

# %%
forg_train
# Out:
# [['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_s_0100f21.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_s_0400f22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_s_0401f19.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_s_0402f24.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_s_0403f19.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_s_0404f21.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_s_0405f18.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_s_0406f22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_s_0407f24.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_s_0408f19.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0205_s_0409f15.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0206_s_0410f20.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0207_s_0411f24.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0208_s_0412f18.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0209_s_0413f16.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0216_s_0420f22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0217_s_0421f24.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0218_s_0422f22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0219_s_0423f11.jpg'],
# ...
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_s_0428f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_s_0428f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_s_0428f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_s_0428f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_s_0428f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_s_0428f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_s_0428f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0224_s_0428f17.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0225_s_0429f22.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0226_s_0430f20.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0227_s_0431f24.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0228_s_0432f23.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f16.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0229_s_0433f24.jpg'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f09.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f03.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f12.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f02.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f05.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f13.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f00.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f11.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f14.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f08.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f04.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f10.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f06.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f01.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f07.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f21.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f24.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f23.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f22.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f19.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f15.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f20.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f18.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f17.jpg',
#   '/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0230_s_0434f16.jpg']]

# %%
# orig_train, orig_val, orig_test = orig_groups[0][:30], orig_groups[0][30:40], orig_groups[0][40:55]
# forg_train, forg_val, forg_test = forg_groups[0][:30], forg_groups[0][30:40], forg_groups[0][40:55]

# %%
orig_train
# Out:
# [['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_10_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_11_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_12_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_13_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_14_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_15_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_16_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_17_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_18_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_19_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_1_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_20_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_21_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_22_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_23_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_24_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_25_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_26_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_27_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_27_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_27_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_27_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_27_13.png',
# ...
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_31_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_32_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_33_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_34_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_35_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_36_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_org/original_37_9.png']]

# %%
forg_train
# Out:
# [['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_10_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_11_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_12_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_13_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_14_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_15_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_16_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_17_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_18_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_19_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_1_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_20_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_21_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_22_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_23_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_24_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_25_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_26_7.png',
# ...
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_32_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_33_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_34_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_35_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_36_9.png'],
#  ['/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_1.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_10.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_11.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_12.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_13.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_14.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_15.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_16.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_17.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_18.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_19.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_2.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_20.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_21.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_22.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_23.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_24.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_3.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_4.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_5.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_6.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_7.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_8.png',
#   '/content/drive/MyDrive/SignatureVerificationCylab/cedar_signet/cedar_dataset/full_forg/forgeries_37_9.png']]

# %%
def get_ids(filename):
  id = filename.split("_")[0]
  return id

# %%
forg_train_ids = {get_ids(os.path.basename(file_path)) for user in forg_train for file_path in user}
orig_train_ids = {get_ids(os.path.basename(file_path)) for user in orig_train for file_path in user}

# %%
forg_val_ids = {get_ids(os.path.basename(file_path)) for user in forg_val for file_path in user}
orig_val_ids = {get_ids(os.path.basename(file_path)) for user in orig_val for file_path in user}

# %%
forg_test_ids = {get_ids(os.path.basename(file_path)) for user in forg_test for file_path in user}
orig_test_ids = {get_ids(os.path.basename(file_path)) for user in orig_test for file_path in user}

# %%
forg_train_ids;

# %%
assert (forg_train_ids == orig_train_ids)
assert (forg_val_ids == orig_val_ids)
assert (forg_test_ids == orig_test_ids)

# %%
# All the images will be converted to the same size before processing
img_h, img_w = 155, 220

# %%
import matplotlib.pyplot as plt
import numpy as np

def create_df(filename):

  root = "/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign"

  file_path = os.path.join(root, filename)

  df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)

  df.columns = ["X", "Y", "timestamps", "azimuth angle","pen up orientation", "pressure"]

  return df


def plot_signature(df, filename):
    x = df.X
    y = df.Y
    z = df.timestamps

    idx = np.argsort(x)

    p0 = min(z)
    ind_p0 = [i for i, v in enumerate(z) if v == p0]
    vnan = np.empty((len(ind_p0), 1))
    x2 = x[idx]
    x2[ind_p0] = vnan
    y2 = y[idx]
    y2[ind_p0] = vnan

    alto = max(y2) - min(y2)
    ancho = max(x2) - min(x2)
    relacion = alto / ancho

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.plot(x, y, 'k', linewidth=2)
    ax.set_yticks([])
    ax.set_xticks([])
    ax.set_position([0.05, 0.05, .9, .9], which='active')
    sign_img = filename.split(".")[0] + ".jpg"
    root = "/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images"
    file_path = os.path.join(root, sign_img)
    plt.savefig(file_path, format='jpeg')
    # plt.show()

# %%
def create_image_from_filename(filename, filename_txt = False):
  current_images = "/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images"
  if filename_txt:
    if filename.split(".")[0] + ".jpg" not in os.listdir(current_images):
      #filename with txt extension
      df = create_df(filename)
      plot_signature(df, filename)
  else:
    #filename with jpg extension
    if filename not in os.listdir(current_images):
      txt_filename = filename.split(".")[0] + ".txt" #necessary because plot signature expects a text format
      df = create_df(txt_filename)
      plot_signature(df, txt_filename)

# %%
def create_image_from_userid(df, id):
  extracted_df = df[df["user id"]==id]
  extracted_df = extracted_df.reset_index()

  for index in range(extracted_df.shape[0]):
    filename = extracted_df["filename"].iloc[index]
    create_image_from_filename(filename, True)

# %%
orig_train

for user in orig_train:
  for file_path in user:
    if file_path not in os.listdir("/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images"):
      print(f"{file_path} not here")
# Out:
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v11.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v12.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v05.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v04.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v09.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v13.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v16.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v10.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v15.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v03.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v06.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v17.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v14.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v08.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v07.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v21.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v20.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v22.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v23.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v18.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v24.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0001_g_0100v19.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v14.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v18.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v19.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v10.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v06.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v20.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v13.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v08.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v16.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v17.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v04.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v22.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v24.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v21.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v23.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v03.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v09.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v05.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v12.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v11.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v15.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0196_g_0400v07.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v11.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v07.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v04.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v10.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v09.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v13.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v06.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v12.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v08.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v03.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v05.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v15.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v24.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v17.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v16.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v21.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v23.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v19.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v14.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v22.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v20.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0197_g_0401v18.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v05.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v14.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v15.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v06.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v10.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v07.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v04.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v11.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v13.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v09.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v12.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v03.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v16.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v08.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v20.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v24.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v18.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v19.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v21.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v23.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v17.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0198_g_0402v22.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v16.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v09.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v04.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v12.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v06.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v13.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v14.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v15.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v03.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v10.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v08.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v05.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v11.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v07.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v17.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v24.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v19.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v21.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v18.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v23.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v20.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0199_g_0403v22.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v15.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v08.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v16.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v12.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v07.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v03.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v10.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v06.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v09.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v14.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v11.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v05.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v13.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v04.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v17.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v24.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v22.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v20.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v21.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v19.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v23.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0200_g_0404v18.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v04.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v12.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v11.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v06.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v13.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v05.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v15.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v07.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v10.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v08.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v09.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v03.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v14.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v20.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v21.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v24.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v18.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v19.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v22.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v23.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v16.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0201_g_0405v17.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v07.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v04.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v06.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v03.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v05.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v17.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v16.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v09.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v15.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v13.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v18.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v14.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v10.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v11.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v08.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v12.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v24.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v19.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v22.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v21.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v20.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0202_g_0406v23.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v11.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v06.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v10.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v09.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v08.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v04.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v03.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v07.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v05.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v13.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v15.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v17.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v14.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v16.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v18.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v19.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v12.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v24.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v21.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v20.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v22.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0203_g_0407v23.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v00.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v01.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v02.jpg not here
# /content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images/u0204_g_0408v08.jpg not here
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-a2ac4ac6e207> in <cell line: 3>()
#       3 for user in orig_train:
#       4   for file_path in user:
# ----> 5     if file_path not in os.listdir("/content/drive/MyDrive/SignatureVerificationCylab/MCYT_from_DeepSign_Images"):
#       6       print(f"{file_path} not here")
#
# KeyboardInterrupt:

# %%
for id in signers_train:
  create_image_from_userid(mcyt_df, id)

# %%
for id in signers_val:
  create_image_from_userid(mcyt_df, id)
# Out:
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)
# <ipython-input-68-5685d438d87b>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, delimiter = '\s', skiprows = 1)

# %%
for id in signers_test:
  create_image_from_userid(mcyt_df, id)

# %%
# orig_img_names = random.sample(orig_train[k], 2)

# %%
# forg_img_name = random.sample(forg_train[k], 1)
# forg_img_name

# %%
def visualize_sample_signature():
    '''Function to randomly select a signature from train set and
    print two genuine copies and one forged copy'''
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (10, 10))
    k = np.random.randint(len(orig_train))
    orig_img_names = random.sample(orig_train[k], 2)
    # print(orig_img_names)
    forg_img_name = random.sample(forg_train[k], 1)
    orig_img1 = cv2.imread(orig_img_names[0], 0)
    orig_img2 = cv2.imread(orig_img_names[1], 0)
    forg_img = plt.imread(forg_img_name[0], 0)
    # print(forg_img_name)
    orig_img1 = cv2.resize(orig_img1, (img_w, img_h))
    orig_img2 = cv2.resize(orig_img2, (img_w, img_h))
    forg_img = cv2.resize(forg_img, (img_w, img_h))

    ax1.imshow(orig_img1, cmap = 'gray')
    ax2.imshow(orig_img2, cmap = 'gray')
    ax3.imshow(forg_img, cmap = 'gray')

    ax1.set_title('Genuine Copy')
    ax1.axis('off')
    ax2.set_title('Genuine Copy')
    ax2.axis('off')
    ax3.set_title('Forged Copy')
    ax3.axis('off')

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
visualize_sample_signature()

# %%
import threading
def generate_batch(orig_groups, forg_groups, batch_size = 128):
    '''Function to generate a batch of data with batch_size number of data points
    Half of the data points will be Genuine-Genuine pairs and half will be Genuine-Forged pairs'''

    lock = threading.Lock()
    with lock:
      while True:
          orig_pairs = []
          forg_pairs = []
          gen_gen_labels = []
          gen_for_labels = []
          all_pairs = []
          all_labels = []

          # Here we create pairs of Genuine-Genuine image names and Genuine-Forged image names
          # For every person we have 24 genuine signatures, hence we have
          # 24 choose 2 = 276 Genuine-Genuine image pairs for one person.
          # To make Genuine-Forged pairs, we pair every Genuine signature of a person
          # with 12 randomly sampled Forged signatures of the same person.
          # Thus we make 24 * 12 = 300 Genuine-Forged image pairs for one person.
          # In all we have 120 person's data in the training data.
          # Total no. of Genuine-Genuine pairs = 120 * 276 = 33120
          # Total number of Genuine-Forged pairs = 120 * 300 = 36000
          # Total no. of data points = 33120 + 36000 = 69120
          for orig, forg in zip(orig_groups, forg_groups):
              orig_pairs.extend(list(itertools.combinations(orig, 2)))
              for i in range(len(forg)):
                  forg_pairs.extend(list(itertools.product(orig[i:i+1], random.sample(forg, 12))))

          # Label for Genuine-Genuine pairs is 1
          # Label for Genuine-Forged pairs is 0
          gen_gen_labels = [1]*len(orig_pairs)
          gen_for_labels = [0]*len(forg_pairs)

          # Concatenate all the pairs together along with their labels and shuffle them
          all_pairs = orig_pairs + forg_pairs

          all_labels = gen_gen_labels + gen_for_labels
          del orig_pairs, forg_pairs, gen_gen_labels, gen_for_labels
          all_pairs, all_labels = shuffle(all_pairs, all_labels)

          # Note the lists above contain only the image names and
          # actual images are loaded and yielded below in batches
          # Below we prepare a batch of data points and yield the batch
          # In each batch we load "batch_size" number of image pairs
          # These images are then removed from the original set so that
          # they are not added again in the next batch.

          k = 0
          pairs=[np.zeros((batch_size, img_h, img_w, 1)) for i in range(2)]
          targets=np.zeros((batch_size,))
          for ix, pair in enumerate(all_pairs):
              img1 = cv2.imread(pair[0], 0)
              img2 = cv2.imread(pair[1], 0)
              # print(img1)
              # print(img2)
              img1 = cv2.resize(img1, (img_w, img_h))
              img2 = cv2.resize(img2, (img_w, img_h))
              img1 = np.array(img1, dtype = np.float64)
              img2 = np.array(img2, dtype = np.float64)
              img1 /= 255
              img2 /= 255
              img1 = img1[..., np.newaxis]
              img2 = img2[..., np.newaxis]
              pairs[0][k, :, :, :] = img1
              pairs[1][k, :, :, :] = img2
              targets[k] = all_labels[ix]
              k += 1
              if k == batch_size:
                  yield pairs, targets
                  k = 0
                  pairs=[np.zeros((batch_size, img_h, img_w, 1)) for i in range(2)]


                  targets=np.zeros((batch_size,))

# %%
def euclidean_distance(vects):
    '''Compute Euclidean Distance between two vectors'''
    x, y = vects
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

def contrastive_loss(y_true, y_pred):
    '''Contrastive loss from Hadsell-et-al.'06
    http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    '''
    margin = 1
    return K.mean(y_true * K.square(y_pred) + (1 - y_true) * K.square(K.maximum(margin - y_pred, 0)))

# %%
def create_base_network_signet(input_shape):

    seq = Sequential()
    seq.add(Convolution2D(96, (11, 11), activation='relu', name='conv1_1', strides=(4,4), input_shape= input_shape,
                        kernel_initializer='glorot_uniform', data_format='channels_last'))
    seq.add(BatchNormalization(epsilon=1e-06, axis=1, momentum=0.9))
    seq.add(MaxPooling2D((3,3), strides=(2, 2)))
    seq.add(ZeroPadding2D((2, 2),))

    seq.add(Convolution2D(256, (5, 5), activation='relu', name='conv2_1', strides=(1, 1), kernel_initializer='glorot_uniform'))
    seq.add(BatchNormalization(epsilon=1e-06, axis=1, momentum=0.9))
    seq.add(MaxPooling2D((3,3), strides=(2, 2)))
    seq.add(Dropout(0.3))# added extra
    seq.add(ZeroPadding2D((1, 1)))

    seq.add(Convolution2D(384, (3, 3), activation='relu', name='conv3_1', strides=(1, 1), kernel_initializer='glorot_uniform'))
    seq.add(ZeroPadding2D((1, 1)))

    seq.add(Convolution2D(256, (3, 3), activation='relu', name='conv3_2', strides=(1, 1), kernel_initializer='glorot_uniform'))
    seq.add(MaxPooling2D((3,3), strides=(2, 2)))
    seq.add(Dropout(0.3))# added extra
#    model.add(SpatialPyramidPooling([1, 2, 4]))
    seq.add(Flatten(name='flatten'))
    seq.add(Dense(1024, kernel_regularizer=l2(0.0005), activation='relu', kernel_initializer='glorot_uniform'))
    seq.add(Dropout(0.5))

    seq.add(Dense(128, kernel_regularizer=l2(0.0005), activation='relu', kernel_initializer='glorot_uniform')) # softmax changed to relu

    print (seq.summary())
    return seq

def compute_accuracy_roc(predictions, labels):
   # Compute ROC accuracy with a range of thresholds on distances.
   dmax = np.max(predictions)
   dmin = np.min(predictions)
   nsame = np.sum(labels == 1)
   ndiff = np.sum(labels == 0)

   step = 0.01
   max_acc = 0

   for d in np.arange(dmin, dmax+step, step):
       idx1 = predictions.ravel() <= d
       idx2 = predictions.ravel() > d

       tpr = float(np.sum(labels[idx1] == 1)) / nsame
       tnr = float(np.sum(labels[idx2] == 0)) / ndiff
       acc = 0.5 * (tpr + tnr)
#       print ('ROC', acc, tpr, tnr)

       if (acc > max_acc):
           max_acc = acc

   return max_acc

def compute_accuracy(predictions, labels):
    """ Compute classification accuracy with a fixed threshold on distances.
    """
    return labels[predictions.ravel() < 0.5].mean()
    # return np.mean(labels==(predictions.ravel() > 0.5))

# %%
input_shape=(img_h, img_w, 1)

# %%
# istance = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([processed_a, processed_b])

# model = Model(inputs=[input_a, input_b], outputs=distance)

# # compile model
# rms = RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08)
# adadelta = Adadelta()
# model.compile(loss=contrastive_loss, optimizer=rms)
# model.fit([tr_pairs[:, 0], tr_pairs[:, 1]], tr_y, batch_size=batch_size, epochs=epochs)
# model.save('../SiameseData/Signet_Models/cedar_original/model.h5')
# #

# %%
# network definition
base_network = create_base_network_signet(input_shape)

input_a = Input(shape=(input_shape))
input_b = Input(shape=(input_shape))

# because we re-use the same instance `base_network`,
# the weights of the network
# will be shared across the two branches
processed_a = base_network(input_a)
processed_b = base_network(input_b)

# Compute the Euclidean distance between the two vectors in the latent space
distance = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([processed_a, processed_b])

model = Model(inputs=[input_a, input_b], outputs=distance)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1_1 (Conv2D)            (None, 37, 53, 96)        11712
#
#  batch_normalization_8 (Batc  (None, 37, 53, 96)       148
#  hNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 18, 26, 96)       0
#  g2D)
#
#  zero_padding2d_12 (ZeroPadd  (None, 22, 30, 96)       0
#  ing2D)
#
#  conv2_1 (Conv2D)            (None, 18, 26, 256)       614656
#
#  batch_normalization_9 (Batc  (None, 18, 26, 256)      72
#  hNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 8, 12, 256)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 8, 12, 256)        0
#
#  zero_padding2d_13 (ZeroPadd  (None, 10, 14, 256)      0
#  ing2D)
#
#  conv3_1 (Conv2D)            (None, 8, 12, 384)        885120
#
#  zero_padding2d_14 (ZeroPadd  (None, 10, 14, 384)      0
#  ing2D)
#
#  conv3_2 (Conv2D)            (None, 8, 12, 256)        884992
#
#  max_pooling2d_14 (MaxPoolin  (None, 3, 5, 256)        0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 3, 5, 256)         0
#
#  flatten (Flatten)           (None, 3840)              0
#
#  dense_8 (Dense)             (None, 1024)              3933184
#
#  dropout_14 (Dropout)        (None, 1024)              0
#
#  dense_9 (Dense)             (None, 128)               131200
#
# =================================================================
# Total params: 6,461,084
# Trainable params: 6,460,974
# Non-trainable params: 110
# _________________________________________________________________
# None

# %%
#25 Genuine and 25 Forged for DeepSignDB
batch_sz = 128
num_train_samples = 25*len(orig_train) + 25*len(forg_train)
num_val_samples, num_test_samples = (25*len(orig_val) + 25*len(forg_val)), (25*(len(orig_test)) + 25*(len(forg_test)))
num_train_samples, num_val_samples, num_test_samples
# Out:
# (1500, 500, 750)

# %%
# batch_sz = 128

# %%
# compile model using RMSProp Optimizer and Contrastive loss function defined above
rms = RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08)
model.compile(loss=contrastive_loss, optimizer=rms)

# %%
# Using Keras Callbacks, save the model after every epoch
# Reduce the learning rate by a factor of 0.1 if the validation loss does not improve for 5 epochs
# Stop the training using early stopping if the validation loss does not improve for 12 epochs
callbacks = [
    EarlyStopping(patience=12, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint('./Weights/signet-deepsign-{epoch:03d}.h5', verbose=1, save_weights_only=True)
]

# %%
orig_train;

# %%
results = model.fit_generator(generate_batch(orig_train, forg_train, batch_sz),
                              steps_per_epoch = num_train_samples//batch_sz,
                              epochs = 50,
                              validation_data = generate_batch(orig_val, forg_val, batch_sz),
                              validation_steps = num_val_samples//batch_sz,
                              callbacks = callbacks)
# Out:
# Epoch 1/50
# <ipython-input-132-f20e4ceee046>:1: UserWarning: `model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   results = model.fit_generator(generate_batch(orig_train, forg_train, batch_sz),
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.1015
# Epoch 1: saving model to ./Weights/signet-deepsign-001.h5
# 11/11 [==============================] - 17s 2s/step - batch: 5.0000 - size: 128.0000 - loss: 1.1015 - val_loss: 1.3074 - lr: 1.0000e-06
# Epoch 2/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.1029
# Epoch 2: saving model to ./Weights/signet-deepsign-002.h5
# 11/11 [==============================] - 13s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.1029 - val_loss: 1.2901 - lr: 1.0000e-06
# Epoch 3/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.0978
# Epoch 3: saving model to ./Weights/signet-deepsign-003.h5
# 11/11 [==============================] - 14s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.0978 - val_loss: 1.3356 - lr: 1.0000e-06
# Epoch 4/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.1007
# Epoch 4: saving model to ./Weights/signet-deepsign-004.h5
# 11/11 [==============================] - 14s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.1007 - val_loss: 1.3682 - lr: 1.0000e-06
# Epoch 5/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.1036
# Epoch 5: saving model to ./Weights/signet-deepsign-005.h5
# 11/11 [==============================] - 14s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.1036 - val_loss: 1.3325 - lr: 1.0000e-06
# Epoch 6/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.0979
# Epoch 6: saving model to ./Weights/signet-deepsign-006.h5
# 11/11 [==============================] - 14s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.0979 - val_loss: 1.3018 - lr: 1.0000e-06
# Epoch 7/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.1035
# Epoch 7: saving model to ./Weights/signet-deepsign-007.h5
# 11/11 [==============================] - 13s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.1035 - val_loss: 1.2961 - lr: 1.0000e-06
# Epoch 8/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.1011
# Epoch 8: saving model to ./Weights/signet-deepsign-008.h5
# 11/11 [==============================] - 14s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.1011 - val_loss: 1.3082 - lr: 1.0000e-06
# Epoch 9/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.1002
# Epoch 9: saving model to ./Weights/signet-deepsign-009.h5
# 11/11 [==============================] - 13s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.1002 - val_loss: 1.3354 - lr: 1.0000e-06
# Epoch 10/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.0989
# Epoch 10: saving model to ./Weights/signet-deepsign-010.h5
# 11/11 [==============================] - 13s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.0989 - val_loss: 1.3224 - lr: 1.0000e-06
# Epoch 11/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.0986
# Epoch 11: saving model to ./Weights/signet-deepsign-011.h5
# 11/11 [==============================] - 13s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.0986 - val_loss: 1.3455 - lr: 1.0000e-06
# Epoch 12/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.0975
# Epoch 12: saving model to ./Weights/signet-deepsign-012.h5
# 11/11 [==============================] - 15s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.0975 - val_loss: 1.3626 - lr: 1.0000e-06
# Epoch 13/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.0949
# Epoch 13: saving model to ./Weights/signet-deepsign-013.h5
# 11/11 [==============================] - 13s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.0949 - val_loss: 1.3630 - lr: 1.0000e-06
# Epoch 14/50
# 11/11 [==============================] - ETA: 0s - batch: 5.0000 - size: 128.0000 - loss: 1.0967
# Epoch 14: saving model to ./Weights/signet-deepsign-014.h5
# 11/11 [==============================] - 13s 1s/step - batch: 5.0000 - size: 128.0000 - loss: 1.0967 - val_loss: 1.3439 - lr: 1.0000e-06
# Epoch 14: early stopping

# %%
# Extract loss values and epoch numbers from history
loss_values = results.history['loss']
epochs = range(1, len(loss_values) + 1)

# Plot the loss over epochs
plt.plot(epochs, loss_values, 'b', label='Training Loss')
plt.title('Training Loss DeepSign dataset')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
def compute_accuracy_roc(predictions, labels):
    '''Compute ROC accuracy with a range of thresholds on distances.
    '''
    dmax = np.max(predictions)
    dmin = np.min(predictions)
    nsame = np.sum(labels == 1)
    ndiff = np.sum(labels == 0)

    step = 0.01
    max_acc = 0
    best_thresh = -1

    for d in np.arange(dmin, dmax+step, step):
        idx1 = predictions.ravel() <= d
        idx2 = predictions.ravel() > d

        tpr = float(np.sum(labels[idx1] == 1)) / nsame
        tnr = float(np.sum(labels[idx2] == 0)) / ndiff
        acc = 0.5 * (tpr + tnr)
#       print ('ROC', acc, tpr, tnr)

        if (acc > max_acc):
            max_acc, best_thresh = acc, d

    return max_acc, best_thresh

# %%
model.load_weights('./Weights/signet-deepsign-014.h5')

# %%
test_gen = generate_batch(orig_test, forg_test, 1)
pred, tr_y = [], []
for i in range(num_test_samples):
    (img1, img2), label = next(test_gen)
    tr_y.append(label)
    pred.append(model.predict([img1, img2])[0][0])

# %%
tr_acc, threshold = compute_accuracy_roc(np.array(pred), np.array(tr_y))
tr_acc, threshold
# Out:
# (0.5616972069026864, 0.01323942955583334)

# %%
def predict_score():
    '''Predict distance score and classify test images as Genuine or Forged'''
    test_point, test_label = next(test_gen)
    img1, img2 = test_point[0], test_point[1]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 10))
    ax1.imshow(np.squeeze(img1), cmap='gray')
    ax2.imshow(np.squeeze(img2), cmap='gray')
    ax1.set_title('Genuine')
    if test_label == 1:
        ax2.set_title('Genuine')
    else:
        ax2.set_title('Forged')
    ax1.axis('off')
    ax2.axis('off')
    plt.show()
    result = model.predict([img1, img2])
    diff = result[0][0]
    print("Difference Score = ", diff)
    if diff > threshold:
        print("Its a Forged Signature")
    else:
        print("Its a Genuine Signature")

# %%
predict_score()
# Out:
# Difference Score =  0.007407747
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.011315809
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.009449584
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.008281685
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.018406715
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.012128324
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.013246671
# Its a Forged Signature

# %%
predict_score()
# Out:
# Difference Score =  0.00811187
# Its a Genuine Signature

# %%
predict_score()
# Out:
# Difference Score =  0.011265503
# Its a Genuine Signature
